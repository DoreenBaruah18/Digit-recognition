# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Dataset

# %%
(x_train,y_train),(x_test,y_test)=keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 6s 1us/step

# %% [markdown]
# # Check Shape

# %% [markdown]
# print(x_train.shape)
# print(x_test.shape)

# %% [markdown]
# # Normalizing Data

# %%
x_train=x_train/255.0
x_test=x_test/255.0

# %% [markdown]
# # Build Model

# %%
model=keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128,activation='relu'),
    keras.layers.Dense(10,activation='softmax')
])

# %% [markdown]
# # Compile Model

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy'
,
              metrics=['accuracy'])

# %% [markdown]
# # Train Model

# %%
model.fit(x_train,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9266 - loss: 0.2597
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9656 - loss: 0.1137
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9765 - loss: 0.0780
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9825 - loss: 0.0577
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9862 - loss: 0.0447

# %% [markdown]
# # Evaluate Model

# %%
test_loss , test_acc=model.evaluate(x_test , y_test)
print("Test accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9755 - loss: 0.0822
# Test accuracy: 0.9754999876022339

# %% [markdown]
# # Prediction

# %%
prediction=model.predict(x_test)
print(prediction[0])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# [1.0248090e-07 2.6152284e-08 6.5858226e-06 8.0634010e-05 1.5026281e-11
#  1.8188375e-09 1.3813714e-11 9.9991262e-01 4.2495120e-08 1.3339681e-07]

# %% [markdown]
# # Showing image and prediction

# %%
plt.imshow(x_test[0],cmap='grey')
plt.title(f"Predicted:{prediction[0].argmax()}")
plt.show()
